# %%
import sys

sys.path.append('../')

import matplotlib.pyplot as plt

# %%
import stochrare as sr

# %%
import interactive_ams as iams

# %%
# %matplotlib widget
iams.main()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/envs/python3.9/lib/python3.9/site-packages/ipympl/backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File ~/anaconda3/envs/python3.9/lib/python3.9/site-packages/matplotlib/backends/backend_webagg_core.py:492, in FigureManagerWebAgg.handle_json(self, content)
#     491 def handle_json(self, content):
# --> 492     self.canvas.handle_event(content)
#
# File ~/anaconda3/envs/python3.9/lib/python3.9/site-packages/matplotlib/backends/backend_webagg_core.py:287, in FigureCanvasWebAggCore.handle_event(self, event)
#     284 e_type = event['type']
# ...

# %%
fig,ax = plt.subplots()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
l = ax.axhline(y=0.3)

# %%
ax.lines[0]

# %%
ax.lines.remove(l)
